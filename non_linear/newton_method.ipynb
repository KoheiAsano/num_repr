# %%
from sympy import symbols
x, y = symbols('x,y')
expr = 2*x + 3*y
print(type(expr))
print(expr)
print(expr.diff(x))
print(expr.diff(x).subs((x,y),(2,2)))
# Out:
# <class 'sympy.core.add.Add'>
# 2*x + 3*y
# 2
# 2

# %%
# one-variable newton!
from sympy.parsing.sympy_parser import parse_expr
expr = parse_expr(str(input()))
expr_p = expr.diff(x)
N = 100 # iteration num
X = -7.0 # initial value
for i in range(N):
    X = X - expr.subs(x, X)/expr_p.subs(x, X)
    print(X)
# 4*(3-x)**3 - 6
# x**3 - 10*x**2 - 75*x + 100
# Out:
#  x**3 - 10*x**2 - 75*x + 100
# -6.01886792452830
# -5.83129682340727
# -5.82447053885465
# -5.82446159831462
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# -5.82446159829929
# ...
